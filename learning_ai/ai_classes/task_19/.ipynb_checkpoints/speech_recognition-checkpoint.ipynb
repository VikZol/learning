# %% [markdown]
# # **ЗАНЯТИЕ ПО ТРАНСКРИБАЦИИ**

# %% [markdown]
# ## Термины

# %% [markdown]
# Транскрибация - это процесс автоматического преобразования аудиозаписей речи в текстовый формат с использованием технологий искусственного интеллекта. Современные системы транскрибации применяют алгоритмы машинного обучения и обработки естественного языка (NLP) для точного распознования и интерпретации устной речи. Эти системы широко используются для создания текстовых транскриптов разговоров, лекций, подкастов, интервью и других видов устной информации.<br>
# [ГОСТ Р 43.0.3-2020 - "Искусственный интеллект. Термины и определения".]

# %% [markdown]
# ## Технологии транскрибации

# %% [markdown]
# На сегодняшний день существует несколько передовых технологий транскрибации устной речи в текст, которые используют современные методы машинного обучения и обработки естественного языка.
#
# > **Google Speech-to-Text**<br>
# Google предоставляет мощный сервис распознавания речи, который поддерживает множество языков и акцентов. Эта технология использует глубокие нейронные сети для преобразования речи в текст и широко применяется в различных приложениях, от создания субтитров до голосовых помощников.
#
# > **Microsoft Azure Speech Service**<br>
# Azure Speech Service от Microsoft предлагает высокоточную транскрибацию речи, поддерживает множество языков и предоставляет возможности для персонализации моделей распознавания речи под конкретные акценты и терминологию. Это делает его подходящим для корпоративного использования.
#
# > **IBM Watson Speech to Text**<br>
# IBM Watson предлагает сервис для распознавания речи, который использует технологии глубокого обучения. Watson поддерживает транскрибацию в реальном времени и пакетную обработку, что делает его полезным для разнообразных бизнес-приложений, включая контактные центры и анализ данных.
#
# > **Amazon Transcribe**<br>
# Amazon Web Services (AWS) предлагает сервис Amazon Transcribe, который обеспечивает автоматическую транскрибацию аудио и видео файлов. Он поддерживает реальное время и пакетную обработку, а также предоставляет возможности для создания субтитров и анализа контента.
#
# > **Deepgram**<br>
# Deepgram использует специализированные модели глубокого обучения для высокоточной транскрибации речи. Их технологии известны своей способностью обрабатывать большие объемы данных и обеспечивать высокую точность даже в сложных акустических условиях.
#
# > **Whisper by OpenAI**<br>
# Whisper — это модель распознавания речи от OpenAI, известная своей высокой точностью и способностью работать с разными акцентами и шумами. Whisper использует современные методы глубокого обучения и является одной из самых передовых технологий в области транскрибации.
#
# > **Nuance Dragon**<br>
# Nuance Dragon предлагает профессиональные решения для распознавания речи, которые широко используются в медицинской и юридической сферах. Технология Dragon известна своей высокой точностью и возможностью адаптации к конкретной терминологии.
#
# > **Tinkoff VoiceKit**<br>
# Tinkoff VoiceKit предлагает решения для распознавания речи на русском языке, использующие технологии машинного обучения и нейронные сети. Этот сервис адаптирован для работы с русскоязычной аудиторией и применяется в различных сферах, от банковского дела до медицины.

# %% [markdown]
# ## Модуль google.colab

# %% [markdown]
# Модуль *google.colab* - это специализированная библиотека для работы в среде Google Colaboratory, которая предоставляет подмодули с функциями для взаимодействия с Google Диском в частности, загрузки и скачивания файлов, управления выводом и аутентификации пользователей.<br>
# Он содержит несколько подмодулей со следующими функциями:<br>
# > Подмодуль № 1:
# ```
# google.colab.drive
# ```
# Функция:
# ```
# mout(path)
# ```
# Монтирует Google Диск в указанную директорию виртуальной машины Colab для доступа к его содержимому, где (path) представляет собой адресную строку, которая указывает директорию в файловой системе виртуальной машины Colab.<br>
# Пример:
# ```
# from google.colab import drive
# drive.mount('/content/drive')
# ```
#
# > Подмодуль № 2:
# ```
# google.colab.files
# ```
# Функции:
# ```
# upload()
# ```
# Открывает диалоговое окно для загрузки файлов с локального компьютера в Colab.
# ```
# download(filename)
# ```
# Скачивает указанный файл из Colab на локальный компьютер.<br>
# Пример:
# ```
# from google.colab import files
# uploaded = files.upload()  # Загрузка файлов
# files.download('file.txt') # Скачивание файлов
# ```
# где строка 'file.txt' представляет имя файла, который необходимо скачать с виртуальной машины и при необходимости, относительный путь к нему от текущей рабочей директории.
#
# > Подмодуль № 3
# ```
# google.colab.output
# ```
# Функции:
# ```
# clear()
# ```
# Очищает вывод текущей ячейки, а именно удаляет все результаты, которые были выведены на экран этой ячейкой, такие как текст, графики или ошибки. Функция полезна для поддержания чистоты и удобства работы в блокноте, особенно когда часто обновляется и повторно выполняется код.<br>
# Пример:
# ```
# from google.colab import output
# output.clear() # Очистка ячейки
# ```
#
# > Подмодуль № 4
# ```
# google.colab.auth
# ```
# Функция:
# ```
# authenticate_user()
# ```
# Аутентифицирует пользователя для доступа к Google API и другим сервисам Google.<br>
# Пример:
# ```
# from google.colab import auth
# auth.authenticate_user() # Аутентификация пользователя
# ```

# %% [markdown]
# Подключение Google Диска к Google Colab

# %%
from google.colab import drive # импорт подмодуля drive из модуля google.colab
drive.mount('/content/drive')  # Монтирование (подключение) Google Диска в директорию '/content/drive' (файловую систему) виртуальной машины Google Colab
# Out:
# Mounted at /content/drive

# %% [markdown]
# где,<br>
# *google.colab* - специализированный модуль, который содержит несколько подмодулей и функций, предоставляемых Google для работы с Google Colaboratory.<br>
#
# *from* - ключевое слово для импорта конкретного объекта, в данном случае подмодуля  *drive* из модуля *google.colab*.<br>
#
# *google.colab.drive* - подмодуль, который используется для подключения к хранилищу Google Диска и работы с его файлами.<br>
#
# drive.mount('/content/drive') - функция подмодуля *drive*, которая монтирует Google Диск в указанную директорию '/content/drive' виртуальной машины Colab, что делает его содержимое доступным для чтения и записи в папке '/content/drive/MyDrive', как если бы они находились на локальном диске.<br>

# %% [markdown]
# Подключение к файлу

# %%
from IPython.display import Audio
Audio('/content/drive/MyDrive/4. Audio/manager.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # **Подключение библиотек**

# %% [markdown]
# ##Подключение бибдиотеки Pydub

# %%
# !pip install pydub

# %% [markdown]
# Библиотека pydub позволяет производить многие операции со звуковыми файлами (просмотр продолжительности аудио, количество каналов, частоту дискредитации и т.д.)

# %%
from pydub import AudioSegment
music = AudioSegment.from_file(file='/content/drive/MyDrive/4. Audio/manager.mp3',
                               format='mp3')
#определение продолжительности аудио записи, сек
print(music.duration_seconds)
#определение частоты дискретизации
print(music.frame_rate)
#определение количеств каналов  на записи
print(music.channels)
# Out:
# 25.0
# 16000
# 2

# %% [markdown]
# Обрезка аудио

# %%
debaty = AudioSegment.from_file(file='/content/drive/MyDrive/4. Audio/debaty.mp3',
                                format='mp3')

print(debaty.duration_seconds)
print(debaty.frame_rate)
print(debaty.channels)
#представление 40 секунд в миллисекундах
FORTY_SECONDS = 40 * 1000

#обрезка файла при помощи индексации
#возьмем первые 40 секунд аудиозаписи
debaty[:FORTY_SECONDS]
# Out:
# 6854.948571428571
# 44100
# 2
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %% [markdown]
# Сохранение фрагмента аудиофайла в директории Google Colab

# %%
debaty[40000:50000].export('part.mp3', format='mp3')
# Out:
# <_io.BufferedRandom name='part.mp3'>

# %% [markdown]
# # **Google STT**

# %% [markdown]
# ##Подключение библиотеки Google STT

# %%
# !pip install SpeechRecognition
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 31.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# Подключаем аудиофайл

# %%
Audio('/content/drive/MyDrive/4. Audio/sample_3.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import speech_recognition as sR
# указываем путь к аудиофайлу
file_path = '/content/drive/MyDrive/4. Audio/sample_3.wav'
# создаем объект класса Recognizer
r = sR.Recognizer()
# читаем файл
with sR.AudioFile(file_path) as source:
  audio = r.record(source)
# выполняем распознование
result = r.recognize_google(audio, language='ru')
result
# Out:
# 'он протор здесь уж целый год и с каждым днём Мечта о киберпространстве становилась все более prizro'

# %% [markdown]
# Ограничение аудиозаписи по времени при помощи параматра duration<br>, где = 4 - секунда до которой будет распознан файл

# %%
with sR.AudioFile(file_path) as source:
  audio = r.record(source, duration=4)
result = r.recognize_google(audio, language='ru')
result
# Out:
# 'он протор здесь уж целый год и'

# %% [markdown]
# Ограничение аудиозаписи по времени при помощи параматра offset<br>, где = 4 - секунда с которой будет распознан файл

# %%
with sR.AudioFile(file_path) as source:
  audio = r.record(source, offset=4)
result = r.recognize_google(audio, language='ru')
result
# Out:
# 'мечта киберпространстве становилось все более prizro'

# %% [markdown]
# Ограничение аудиозаписи по времени при помощи комбинации параметров offset и duration:<br>, где<br>offset= 2 - время в секундах с которого будет распозноваться файл<br>duration=4 - в сукундах до которого будет распознан файл

# %%
with sR.AudioFile(file_path) as source:
  audio = r.record(source, offset=2, duration=4)
result = r.recognize_google(audio, language='ru')
result
# Out:
# 'и с каждым днём Мечта о'

# %% [markdown]
# # **Whisper AI**

# %% [markdown]
# Установка библиотеки Whisper AI

# %%
# !pip install -U openai-whisper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.6/798.6 kB 9.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 52.8 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...

# %%
import whisper
from pprint import pprint
model = whisper.load_model('base')
result = model.transcribe("/content/drive/MyDrive/4. Audio/manager.mp3")
print(result['text'])
# Out:
# 100%|████████████████████████████████████████| 139M/139M [00:00<00:00, 151MiB/s]
#  В принципе, я в свое время это не сильно впечатлило на практике построения сетей для прогнозирования событий в обащем я не веду в рамках движения там рыночные цены очень сложно, потому что тамfiction smoke preachmensные води

# %% [markdown]
# Использование модели medium

# %%
model = whisper.load_model('medium')
result = model.transcribe("/content/drive/MyDrive/4. Audio/manager.mp3")
print(result['text'])
# Out:
# 100%|█████████████████████████████████████| 1.42G/1.42G [00:15<00:00, 96.4MiB/s]
#  В принципе, меня в свое время это не сильно впечатлило на практике построения сетей для прогнозирования событий в будущем. Я не веду в рамках задвижения там рыночной цены. Ну да, довольно сложно, потому что там довольно-таки скачки сильные идут постоянно.

# %% [markdown]
# Использование модели large (хорошо справляется с русским языком, но требует много ресурсов)

# %%
model = whisper.load_model('large')
result = model.transcribe("/content/drive/MyDrive/4. Audio/manager.mp3")
print(result['text'])
# Out:
# 100%|█████████████████████████████████████| 2.88G/2.88G [00:45<00:00, 67.5MiB/s]
#  В принципе, меня в свое время это не сильно впечатлило на практике построения сетей для прогнозирования событий в будущем. Я не имею в виду в рамках движения там рыночной цены. Ну, да, довольно сложно, потому что там довольно-таки скачки сильные идут постоянно, тяжело продвигаться.

# %%
pprint(result)
# Out:
# {'language': 'ru',
#  'segments': [{'avg_logprob': -0.15553044213189018,
#                'compression_ratio': 1.8962962962962964,
#                'end': 11.88,
#                'id': 0,
#                'no_speech_prob': 0.0008215245325118303,
#                'seek': 0,
#                'start': 0.0,
#                'temperature': 0.0,
#                'text': ' В принципе, меня в свое время это не сильно '
#                        'впечатлило на практике построения сетей для '
#                        'прогнозирования событий в будущем.',
#                'tokens': [50365,
#                           2348,
#                           39086,
#                           11,
#                           6885,
#                           740,
#                           42666,
#                           12039,
#                           2691,
#                           1725,
#                           31350,
#                           27163,
#                           35534,
# ...

# %% [markdown]
# Импортируем библиотеку pandas

# %%
import pandas as pd

# %% [markdown]
# Запись всех сегментов в датафрейм для удобного просмотра

# %%
df = pd.DataFrame(result['segments'])
df
# Out:
#    id  seek  start    end                                               text  \
# 0   0     0   0.00  11.88   В принципе, меня в свое время это не сильно в...
# 1   1     0  13.50  16.70   Я не имею в виду в рамках движения там рыночн...
# 2   2     0  17.06  25.00   Ну, да, довольно сложно, потому что там довол...
#
#                                               tokens  temperature  \
# 0  [50365, 2348, 39086, 11, 6885, 740, 42666, 120...          0.0
# 1  [51040, 4857, 1725, 19539, 1148, 740, 6504, 58...          0.0
# 2  [51218, 7571, 11, 8995, 11, 31777, 41016, 11, ...          0.0
#
#    avg_logprob  compression_ratio  no_speech_prob
# 0     -0.15553           1.896296        0.000822
# 1     -0.15553           1.896296        0.000822
# 2     -0.15553           1.896296        0.000822

# %% [markdown]
# Автоматический перевод на английский язык

# %%
model = whisper.load_model("large")
result = model.transcribe("/content/drive/MyDrive/4. Audio/manager.mp3",
                          task="translate")
print(result['text'])
# Out:
#  In principle, it did not impress me much in my time in the practice of building networks to predict events in the future. I do not mean in the context of the promotion of the market price. Well, yes, it is quite difficult, because there are quite strong jumps, it is constantly difficult to get there.

# %% [markdown]
# Использование initial_prompt

# %%
# использование модели medium с параметром initial_prompt
model = whisper.load_model('medium')
result = model.transcribe('/content/drive/MyDrive/4. Audio/manager.mp3',
                          initial_prompt='в рамках движения')
print(result['text'])
# Out:
#  в своем времени это не сильно впечатлило на практике построения сетей для прогнозирования событий в будущем? Я не веду в рамках движения там рыночной цены. Ну да, довольно сложно, потому что там довольно-таки скачки сильные идут постоянно, тяжело дать.

# %% [markdown]
# Распознование языка

# %%
import whisper
# загружаем базовую модель
model = whisper.load_model('base')
# загружаем аудио
audio = whisper.load_audio('/content/drive/MyDrive/4. Audio/manager.mp3')
# извлекаем первые 30 секунд видео (если продолжительность видео короче, то добиваем нулями)
audio = whisper.pad_or_trim(audio)
# получаем log-Mel спектограмму и передаем ее на то же устройство, где находится модель
mel = whisper.log_mel_spectrogram(audio).to(model.device)
# получаем словарь уверенностей распознанного языка
_, probs = model.detect_language(mel)
print(f"Распознанный язык: {max(probs, key=probs.get)}")
# выполняем распознавание речи
options = whisper.DecodingOptions()
result = whisper.decode(model, mel, options)
# выводим полученный текст
print(result.text)
# Out:
# Распознанный язык: ru
# В принципе, я в свое время это не сильно впечатлило на практике построения сетей для прогнозирования событий в обащем я не веду в рамках движения там рыночные цены

# %% [markdown]
# Вывод спектрограммы

# %%
import matplotlib.pyplot as plt
# выведем log-Mel спектрограмму на экран
plt.figure(figsize=(20, 10))
plt.imshow(mel.cpu())
plt.show()

# %%
# полученный словарь со значениями уверенностей всех языков модели
probs
# Out:
# {'it': 3.6605531931854784e-05,
#  'nn': 0.0014923268463462591,
#  'fi': 2.523707371437922e-05,
#  'nl': 4.855945007875562e-06,
#  'cy': 0.00011369714775355533,
#  'da': 2.485255208739545e-06,
#  'fr': 8.595744293415919e-05,
#  'is': 1.396634161210386e-06,
#  'sk': 6.078957085264847e-06,
#  'en': 0.0027523476164788008,
#  'tt': 9.848261584011198e-08,
#  'kk': 8.438008990196977e-06,
#  'mn': 1.2510688065958675e-05,
#  'zh': 0.00024186717928387225,
#  'es': 0.0001546491839690134,
#  'uz': 4.7164570027291575e-09,
#  'lb': 8.985979071951533e-09,
#  'sq': 1.57699832925573e-06,
#  'sd': 4.4008612576362793e-07,
#  'uk': 0.011633481830358505,
#  'su': 6.089664772446213e-09,
#  'tr': 0.0004902528016828001,
#  'he': 3.1176602988125524e-06,
#  'hy': 1.0102162377734203e-05,
#  'ko': 0.00020777802274096757,
#  'vi': 1.7621341612539254e-05,
#  'lt': 5.0526570703368634e-05,
#  'mk': 1.4178232277117786e-06,
#  'lv': 3.78380491383723e-06,
#  'bn': 1.2226048511365661e-06,
# ...

# %% [markdown]
# ## **Использование Whisper по API**

# %% [markdown]
# Установка библиотек

# %%
# !pip install --upgrade openai

# %%
import openai
import getpass
import os
# передаем секретный API токен
openai_key = getpass.getpass("OpenAI API Key:")
os.environ["OPENAI_API_KEY"] = openai_key
openai.api_key = openai_key
# Out:
# OpenAI API Key:··········

# %%
from openai import OpenAI
# создаем экземпляр класса OpenAI
client = OpenAI()
# выполняем чтение файла
audio_file = open("/content/drive/MyDrive/4. Audio/manager.mp3", "rb")
# выполняем транскрибацию
transcript = client.audio.transcriptions.create(model="whisper-1",
                                                file=audio_file)
transcript.text
# Out:
# 'Меня в свое время это не сильно впечатлило на практике построения сетей для прогнозирования событий в будущем. Я имею ввиду в рамках заграждения рыночной цены. Да, довольно сложно, потому что там довольно-таки скачки сильные идут постоянно.'

# %% [markdown]
# Транскрибация + перевод

# %%
# создаем экземпляр класса OpenAI
client = OpenAI()
# выполняем чтение файла
audio_file = open("/content/drive/MyDrive/4. Audio/manager.mp3", "rb")
# выполняем транскрибацию плюс перевод на английский язык
transcript = client.audio.translations.create(model="whisper-1",
                                                file=audio_file)
transcript.text
# Out:
# "In fact, it didn't impress me much at the time, in practice, building networks for forecasting events in the future, I mean, within the framework of the promotion of the market price. Well, yes, it's quite difficult, because there are quite strong jumps, it's hard to predict."

# %% [markdown]
# Использование prompt

# %%
# создаем экземпляр класса OpenAI
client = OpenAI()
# выполняем чтение файла
audio_file = open("/content/drive/MyDrive/4. Audio/manager.mp3", "rb")
# выполняем транскрибацию с использованием параметра prompt
transcript = client.audio.transcriptions.create(model="whisper-1",
                                                file=audio_file,
                                              prompt = 'в рамках движения')

transcript.text
# Out:
# 'В принципе, меня в свое время это не сильно впечатлило на практике построения сетей для прогнозирования событий в будущем. Я имею в виду в рамках движения там рыночной цены. Ну да, довольно сложно, потому что там довольно-таки скачки сильные идут постоянно.'

# %% [markdown]
# Ссылка на документацию для работы с Whisper: https://cookbook.openai.com/examples/whisper_prompting_guide

# %% [markdown]
# # **Tinkoff VoiceKit**

# %% [markdown]
# Tinkoff VoiceKit предлагает решения для распознавания речи на русском языке, использующие технологии машинного обучения и нейронные сети. Этот сервис адаптирован для работы с русскоязычной аудиторией и применяется в различных сферах, от банковского дела до медицины.
